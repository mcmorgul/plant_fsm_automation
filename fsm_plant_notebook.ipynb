# %% [markdown]
# # Finite State Machine for Water and Temperature Automation of a Plant

# %% [markdown]
# In our desgin we are using water (humidity) and temperature sensors. Output of water and temperature sensors are four and three bits. These output bits are inputs of circuit. Sensors take analog information and samples it to a digital signal.
#
# Sample coding for water and temperature sensors are:
#
# **ConditionalUpdate Water (Humidity) Sensor Output Legend:**
# 0%: 0(0000); 10%: 1(0001); 20%: 2(0010);30%: 3(0011); 40%: 4(0100); 50%: 5(0101);
# 60%: 6(0110); 70%: 7(0111); 80%: 13(1101); 90%: 14(1110); 100%: 15(1111)
#
# **Temperature Sensor Output Legend (in Celsius):**
# <17.5: 0(000); 20: 1(001);22.5: 2(010); 25: 3(011); 27.5: 4(100); 30: 5(101); 32.5: 6(110); 35: 7(111);
#
# We have four inputs called **start**, **reset**, **water**, and **temperature**
#
# input **start** controls the POWER, either POWER is ON or OFF
# input **reset**  puts the system into default state.
# input **water** is the output of the humidity sensor
# input **temperature** is the output of the the temperature sensor
#
# We have two outputs called **pump**, **ac**,
#
# output **pump** (water pump): ON (1) or OFF (0)
# output **ac** (Air Conditioning): A/C: Heating (11), Cooling (01) or OFF (00)
#
# We have seven states. For State machine diagram please visit: http://venividiwiki.ee.virginia.edu/mediawiki/index.php/Water_and_Temperature_Automation_of_a_Plant
#
# **SO**: Power is OFF (both pump and ac are closed)
# **S1**: Default state (**pump** is ON and **ac** is OFF)
# **S2**: Default state (**ac** is OFF)
# **S3**: Default state (**ac** is Heating)
# **S4**: Default state (**ac** is Cooling)
# **S5**: Default state (**pump** is ON)
# **S6**: Default state (**pump** is OFF)
#
# Since **S2-S4** and **S5-S6** states are independent. We register two state variable **state_water** and **state_temperature**

# %%
import pyrtl
pyrtl.reset_working_block()

# %% [markdown]
# ## Define wires and registes
# **Input** and **Output** are special type of wire, for hardware match. We need to use **Register** for states to give the decision with ".next"

# %%
start = pyrtl.Input(1, 'start')
reset = pyrtl.Input(1, 'reset')
water = pyrtl.Input(4, 'water')
temperature = pyrtl.Input(3, 'temperature')
pump = pyrtl.Output(1, 'pump')
ac = pyrtl.Output(2, 'ac')
state_water = pyrtl.Register(3, 'state_water') #S0 S1 S5 S6
state_temperature = pyrtl.Register(3, 'state_temperature') #S0 S1 S2 S3 S4

# %% [markdown]
# First new step, let's **enumerate a set of constant to serve as our states**

# %%
S0, S1, S2, S3, S4, S5, S6 = [pyrtl.Const(x, bitwidth=3) for x in range(7)]

# %% [markdown]
# ## Create state transition and logic
# **PyRTL provides a class "ConditionalUpdate"** to provide a predicated update to a registers, wires, and memories.
# It is same as "if-else if-else" conditional states.

# %%
with pyrtl.conditional_assignment:
    with start:  # power is ON
		with reset:  # system in reset
			state_water.next |= S1
			state_temperature.next |= S1
		with pyrtl.otherwise: # functioning
			with (state_water == S0): # if previous state_water is power OFF
				state_water.next |= S1
				with (state_temperature == S0): 
					state_temperature.next |= S1
			with (state_water == S1):
				state_water.next |= S5
				with (state_temperature == S1):
					state_temperature.next |= S2
			with state_water == S5: # pump ON
				with water <= 14: # less than or equal to %90
					state_water.next |= S5
					with state_temperature == S2: #ac OFF
						with temperature < 2: # less than 22,5
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S4
						with pyrtl.otherwise: # between 22,5 and 30
							state_temperature.next |= S2
					with state_temperature == S3: # heat
						with temperature <= 5: # less than 30
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S2
					with state_temperature == S4: #cool
						with temperature <= 2: # less than 22.5
							state_temperature.next |= S2
						with temperature > 2: # higher than 22.5
							state_temperature.next |= S4
				with water > 14: # higher than %90
					state_water.next |= S6
					with state_temperature == S2: #ac OFF
						with temperature < 2: # less than 22,5
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S4
						with pyrtl.otherwise: # between 22,5 and 30
							state_temperature.next |= S2
					with state_temperature == S3: # heat
						with temperature <= 5: # less than 30
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S2
					with state_temperature == S4: #cool
						with temperature <= 2: # less than 22.5
							state_temperature.next |= S2
						with temperature > 2: # higher than 22.5
							state_temperature.next |= S4
			with state_water == S6: # pump OFF
				with water <= 5: # less than or equal to %50
					state_water.next |= S5
					with state_temperature == S2: #ac OFF
						with (temperature <= 5) | (temperature >= 2 ): # between 22,5 and 30
							state_temperature.next |= S2
						with temperature < 2: # less than 22,5
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S4
					with state_temperature == S3: # heat
						with temperature <= 5: # less than 30
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S2
					with state_temperature == S4: #cool
						with temperature <= 2: # less than 22.5
							state_temperature.next |= S2
						with temperature > 2: # higher than 22.5
							state_temperature.next |= S4
				with water > 5: # higher than %50
					state_water.next |= S6
					with state_temperature == S2: #ac OFF
						with (temperature <= 5) | (temperature >= 2 ): # between 22,5 and 30
							state_temperature.next |= S2
						with temperature < 2: # less than 22,5
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S4
					with state_temperature == S3: # heat
						with temperature <= 5: # less than 30
							state_temperature.next |= S3
						with temperature > 5: # higher than 30
							state_temperature.next |= S2
					with state_temperature == S4: #cool
						with temperature <= 2: # less than 22.5
							state_temperature.next |= S2
						with temperature > 2: # higher than 22.5
							state_temperature.next |= S4
			with pyrtl.otherwise:  
				state_water.next |= S1
				state_temperature.next |= S1
    with pyrtl.otherwise:
		state_water.next |= S0 # power OFF
		state_temperature.next |= S0

# %% [markdown]
# **Stae Logic**

# %%
pump <<= (state_water == S1) | (state_water == S5) 
ac <<= 3*(state_temperature == S3) + (state_temperature == S4) # for S3 (heating): ac=11; for S4 (cooling): ac=01

# %% [markdown]
# Now let's **print, build and test our state machine**.

# %%
print('--- plant_FSM Implementation ---')
print(pyrtl.working_block())
print()

sim_trace = pyrtl.SimulationTrace()
sim = pyrtl.Simulation(tracer=sim_trace)
# Out:
# --- plant_FSM Implementation ---
# tmp535/1W <-- s -- const_52_0/1C ((0,))
# tmp557/1W <-- s -- const_54_0/1C ((0,))
# tmp648/1W <-- s -- const_56_0/1C ((0,))
# tmp36/1W <-- s -- const_9_0/1C ((0,))
# tmp458/1W <-- s -- const_47_0/1C ((0,))
# tmp155/1W <-- s -- const_19_0/1C ((0,))
# tmp255/1W <-- s -- const_26_0/1C ((0,))
# tmp515/1W <-- > -- temperature/3I, const_50_5/3C
# tmp346/1W <-- > -- temperature/3I, const_35_5/3C
# tmp292/1W <-- > -- temperature/3I, const_29_5/3C
# tmp217/1W <-- > -- temperature/3I, const_22_5/3C
# tmp256/3W <-- c -- tmp255/1W, const_25_2/2C
# tmp106/1W <-- s -- const_14_0/1C ((0,))
# tmp235/1W <-- s -- const_24_0/1C ((0,))
# tmp328/1W <-- > -- temperature/3I, const_34_5/3C
# tmp652/3W <-- s -- const_57_0/1C ((0, 0, 0))
# tmp421/1W <-- s -- const_42_0/1C ((0,))
# tmp347/1W <-- ~ -- tmp346/1W
# tmp257/1W <-- > -- temperature/3I, tmp256/3W
# tmp293/1W <-- ~ -- tmp292/1W
# tmp158/1W <-- ~ -- reset/1I
# tmp78/1W <-- ~ -- reset/1I
# tmp127/1W <-- ~ -- reset/1I
# tmp185/1W <-- ~ -- reset/1I
# tmp110/1W <-- ~ -- reset/1I
# tmp171/1W <-- ~ -- reset/1I
# tmp27/1W <-- ~ -- reset/1I
# tmp314/1W <-- ~ -- reset/1I
# tmp590/1W <-- ~ -- reset/1I
# tmp281/1W <-- ~ -- reset/1I
# tmp91/1W <-- ~ -- reset/1I
# tmp50/1W <-- ~ -- reset/1I
# tmp62/1W <-- ~ -- reset/1I
# tmp363/1W <-- ~ -- reset/1I
# tmp444/1W <-- ~ -- reset/1I
# tmp348/1W <-- ~ -- reset/1I
# tmp3/1W <-- ~ -- reset/1I
# tmp144/1W <-- ~ -- reset/1I
# tmp203/1W <-- ~ -- reset/1I
# tmp329/1W <-- ~ -- reset/1I
# tmp424/1W <-- ~ -- reset/1I
# tmp384/1W <-- ~ -- reset/1I
# tmp560/1W <-- ~ -- reset/1I
# tmp580/1W <-- ~ -- reset/1I
# tmp516/1W <-- ~ -- reset/1I
# tmp7/1W <-- ~ -- reset/1I
# tmp299/1W <-- ~ -- reset/1I
# tmp258/1W <-- ~ -- reset/1I
# tmp12/1W <-- ~ -- reset/1I
# tmp18/1W <-- ~ -- reset/1I
# tmp461/1W <-- ~ -- reset/1I
# tmp478/1W <-- ~ -- reset/1I
# tmp499/1W <-- ~ -- reset/1I
# tmp39/1W <-- ~ -- reset/1I
# tmp403/1W <-- ~ -- reset/1I
# tmp239/1W <-- ~ -- reset/1I
# tmp539/1W <-- ~ -- reset/1I
# tmp218/1W <-- ~ -- reset/1I
# tmp497/1W <-- > -- temperature/3I, const_49_5/3C
# tmp380/1W <-- s -- const_38_0/1C ((0,))
# tmp376/1W <-- ~ -- tmp347/1W
# tmp400/1W <-- s -- const_40_0/1C ((0,))
# tmp422/4W <-- c -- tmp421/1W, const_41_5/3C
# tmp49/1W <-- > -- temperature/3I, const_10_5/3C
# tmp536/3W <-- c -- tmp535/1W, const_51_2/2C
# tmp90/1W <-- > -- temperature/3I, const_12_5/3C
# tmp75/1W <-- = -- state_temperature/3R, const_3_3/3C
# tmp647/1W <-- = -- state_temperature/3R, const_3_3/3C
# tmp345/1W <-- = -- state_temperature/3R, const_3_3/3C
# tmp200/1W <-- = -- state_temperature/3R, const_3_3/3C
# tmp496/1W <-- = -- state_temperature/3R, const_3_3/3C
# tmp439/1W <-- s -- const_45_0/1C ((0,))
# tmp107/3W <-- c -- tmp106/1W, const_13_2/2C
# tmp277/1W <-- s -- const_28_0/1C ((0,))
# tmp440/3W <-- c -- tmp439/1W, const_44_2/2C
# tmp381/3W <-- c -- tmp380/1W, const_37_2/2C
# tmp437/1W <-- > -- temperature/3I, const_43_5/3C
# tmp581/1W <-- & -- start/1I, tmp580/1W
# tmp404/1W <-- & -- start/1I, tmp403/1W
# tmp79/1W <-- & -- start/1I, tmp78/1W
# tmp204/1W <-- & -- start/1I, tmp203/1W
# tmp159/1W <-- & -- start/1I, tmp158/1W
# tmp479/1W <-- & -- start/1I, tmp478/1W
# tmp600/1W <-- ~ -- start/1I
# tmp425/1W <-- & -- start/1I, tmp424/1W
# tmp445/1W <-- & -- start/1I, tmp444/1W
# tmp601/1W <-- ~ -- start/1I
# tmp145/1W <-- & -- start/1I, tmp144/1W
# tmp1/1W <-- & -- start/1I, reset/1I
# tmp186/1W <-- & -- start/1I, tmp185/1W
# tmp13/1W <-- & -- start/1I, tmp12/1W
# tmp240/1W <-- & -- start/1I, tmp239/1W
# tmp0/1W <-- & -- start/1I, reset/1I
# tmp111/1W <-- & -- start/1I, tmp110/1W
# tmp40/1W <-- & -- start/1I, tmp39/1W
# tmp282/1W <-- & -- start/1I, tmp281/1W
# tmp143/1W <-- > -- water/4I, const_17_14/4C
# tmp124/1W <-- s -- const_16_0/1C ((0,))
# tmp537/1W <-- > -- temperature/3I, tmp536/3W
# tmp401/3W <-- c -- tmp400/1W, const_39_2/2C
# tmp382/1W <-- > -- temperature/3I, tmp381/3W
# tmp201/1W <-- > -- temperature/3I, const_21_5/3C
# tmp517/1W <-- & -- start/1I, tmp516/1W
# tmp311/1W <-- s -- const_33_0/1C ((0,))
# tmp19/1W <-- & -- start/1I, tmp18/1W
# tmp300/1W <-- & -- start/1I, tmp299/1W
# tmp385/1W <-- & -- start/1I, tmp384/1W
# tmp8/1W <-- & -- start/1I, tmp7/1W
# tmp172/1W <-- & -- start/1I, tmp171/1W
# tmp276/1W <-- = -- state_water/3R, const_6_6/3C
# tmp645/1W <-- = -- state_water/3R, const_5_5/3C
# tmp24/1W <-- = -- state_water/3R, const_5_5/3C
# tmp477/1W <-- > -- temperature/3I, const_48_5/3C
# tmp251/1W <-- ~ -- tmp200/1W
# tmp270/1W <-- ~ -- tmp200/1W
# tmp219/1W <-- & -- start/1I, tmp218/1W
# tmp128/1W <-- & -- start/1I, tmp127/1W
# tmp330/1W <-- & -- start/1I, tmp329/1W
# tmp92/1W <-- & -- start/1I, tmp91/1W
# tmp561/1W <-- & -- start/1I, tmp560/1W
# tmp498/1W <-- ~ -- tmp497/1W
# tmp436/1W <-- = -- state_temperature/3R, const_2_2/3C
# tmp291/1W <-- = -- state_temperature/3R, const_2_2/3C
# tmp154/1W <-- = -- state_temperature/3R, const_2_2/3C
# tmp35/1W <-- = -- state_temperature/3R, const_2_2/3C
# tmp249/1W <-- ~ -- tmp154/1W
# tmp213/1W <-- ~ -- tmp154/1W
# tmp228/1W <-- ~ -- tmp154/1W
# tmp268/1W <-- ~ -- tmp154/1W
# tmp574/1W <-- ~ -- tmp496/1W
# tmp553/1W <-- ~ -- tmp496/1W
# tmp312/3W <-- c -- tmp311/1W, const_32_2/2C
# tmp383/1W <-- ~ -- tmp382/1W
# tmp137/1W <-- ~ -- tmp75/1W
# tmp120/1W <-- ~ -- tmp75/1W
# tmp572/1W <-- ~ -- tmp436/1W
# tmp528/1W <-- ~ -- tmp436/1W
# tmp551/1W <-- ~ -- tmp436/1W
# tmp511/1W <-- ~ -- tmp436/1W
# tmp278/4W <-- c -- tmp277/1W, const_27_5/3C
# tmp108/1W <-- > -- temperature/3I, tmp107/3W
# tmp418/1W <-- ~ -- tmp383/1W
# tmp202/1W <-- ~ -- tmp201/1W
# tmp538/1W <-- ~ -- tmp537/1W
# tmp279/1W <-- > -- water/4I, tmp278/4W
# tmp598/1W <-- ~ -- tmp276/1W
# tmp588/1W <-- ~ -- tmp276/1W
# tmp231/1W <-- ~ -- tmp202/1W
# tmp109/1W <-- ~ -- tmp108/1W
# tmp313/1W <-- < -- temperature/3I, tmp312/3W
# tmp305/1W <-- ~ -- tmp24/1W
# tmp430/1W <-- ~ -- tmp24/1W
# tmp484/1W <-- ~ -- tmp24/1W
# tmp390/1W <-- ~ -- tmp24/1W
# tmp522/1W <-- ~ -- tmp24/1W
# tmp354/1W <-- ~ -- tmp24/1W
# tmp335/1W <-- ~ -- tmp24/1W
# tmp505/1W <-- ~ -- tmp24/1W
# tmp586/1W <-- ~ -- tmp24/1W
# tmp450/1W <-- ~ -- tmp24/1W
# tmp566/1W <-- ~ -- tmp24/1W
# tmp467/1W <-- ~ -- tmp24/1W
# tmp287/1W <-- ~ -- tmp24/1W
# tmp545/1W <-- ~ -- tmp24/1W
# tmp369/1W <-- ~ -- tmp24/1W
# tmp320/1W <-- ~ -- tmp24/1W
# tmp409/1W <-- ~ -- tmp24/1W
# tmp596/1W <-- ~ -- tmp24/1W
# tmp86/1W <-- ~ -- tmp35/1W
# tmp135/1W <-- ~ -- tmp35/1W
# tmp118/1W <-- ~ -- tmp35/1W
# tmp99/1W <-- ~ -- tmp35/1W
# tmp4/1W <-- & -- start/1I, tmp3/1W
# tmp315/1W <-- & -- start/1I, tmp314/1W
# tmp438/1W <-- ~ -- tmp437/1W
# tmp402/1W <-- > -- temperature/3I, tmp401/3W
# tmp423/1W <-- > -- water/4I, tmp422/4W
# tmp364/1W <-- & -- start/1I, tmp363/1W
# tmp156/3W <-- c -- tmp155/1W, const_18_2/2C
# tmp591/1W <-- & -- start/1I, tmp590/1W
# tmp259/1W <-- & -- start/1I, tmp258/1W
# tmp441/1W <-- < -- temperature/3I, tmp440/3W
# tmp349/1W <-- & -- start/1I, tmp348/1W
# tmp577/1W <-- ~ -- tmp538/1W
# tmp140/1W <-- ~ -- tmp109/1W
# tmp342/1W <-- ~ -- tmp313/1W
# tmp462/1W <-- & -- start/1I, tmp461/1W
# tmp6/1W <-- = -- state_temperature/3R, const_0_0/3C
# tmp2/1W <-- = -- state_water/3R, const_0_0/3C
# tmp73/1W <-- ~ -- tmp49/1W
# tmp170/1W <-- > -- temperature/3I, const_20_5/3C
# tmp415/1W <-- ~ -- tmp345/1W
# tmp396/1W <-- ~ -- tmp345/1W
# tmp28/1W <-- & -- start/1I, tmp27/1W
# tmp394/1W <-- ~ -- tmp291/1W
# tmp413/1W <-- ~ -- tmp291/1W
# tmp373/1W <-- ~ -- tmp291/1W
# tmp358/1W <-- ~ -- tmp291/1W
# tmp459/3W <-- c -- tmp458/1W, const_46_2/2C
# tmp157/1W <-- < -- temperature/3I, tmp156/3W
# tmp37/3W <-- c -- tmp36/1W, const_8_2/2C
# tmp125/3W <-- c -- tmp124/1W, const_15_2/2C
# tmp25/1W <-- > -- water/4I, const_7_14/4C
# tmp236/3W <-- c -- tmp235/1W, const_23_2/2C
# tmp602/3W <-- x -- tmp0/1W, state_water/3R, const_1_1/3C
# tmp611/3W <-- x -- tmp1/1W, state_temperature/3R, const_1_1/3C
# tmp11/1W <-- = -- state_water/3R, const_1_1/3C
# tmp644/1W <-- = -- state_water/3R, const_1_1/3C
# tmp17/1W <-- = -- state_temperature/3R, const_1_1/3C
# tmp500/1W <-- & -- start/1I, tmp499/1W
# tmp651/1W <-- = -- state_temperature/3R, const_4_4/3C
# tmp234/1W <-- = -- state_temperature/3R, const_4_4/3C
# tmp534/1W <-- = -- state_temperature/3R, const_4_4/3C
# tmp105/1W <-- = -- state_temperature/3R, const_4_4/3C
# tmp379/1W <-- = -- state_temperature/3R, const_4_4/3C
# tmp531/1W <-- ~ -- tmp498/1W
# tmp362/1W <-- > -- temperature/3I, const_36_5/3C
# tmp280/1W <-- ~ -- tmp279/1W
# tmp76/1W <-- > -- temperature/3I, const_11_5/3C
# tmp649/2W <-- c -- tmp648/1W, tmp647/1W
# tmp442/1W <-- ~ -- tmp441/1W
# tmp558/3W <-- c -- tmp557/1W, const_53_2/2C
# tmp63/1W <-- & -- start/1I, tmp62/1W
# tmp540/1W <-- & -- start/1I, tmp539/1W
# tmp51/1W <-- & -- start/1I, tmp50/1W
# tmp294/1W <-- s -- const_31_0/1C ((0,))
# tmp182/1W <-- ~ -- tmp157/1W
# tmp196/1W <-- ~ -- tmp157/1W
# tmp501/1W <-- ~ -- tmp2/1W
# tmp29/1W <-- ~ -- tmp2/1W
# tmp146/1W <-- ~ -- tmp2/1W
# tmp386/1W <-- ~ -- tmp2/1W
# tmp582/1W <-- ~ -- tmp2/1W
# tmp41/1W <-- ~ -- tmp2/1W
# tmp562/1W <-- ~ -- tmp2/1W
# tmp64/1W <-- ~ -- tmp2/1W
# tmp220/1W <-- ~ -- tmp2/1W
# tmp160/1W <-- ~ -- tmp2/1W
# tmp9/1W <-- & -- tmp8/1W, tmp2/1W
# tmp480/1W <-- ~ -- tmp2/1W
# tmp301/1W <-- ~ -- tmp2/1W
# tmp93/1W <-- ~ -- tmp2/1W
# tmp463/1W <-- ~ -- tmp2/1W
# tmp205/1W <-- ~ -- tmp2/1W
# tmp283/1W <-- ~ -- tmp2/1W
# tmp446/1W <-- ~ -- tmp2/1W
# tmp426/1W <-- ~ -- tmp2/1W
# tmp541/1W <-- ~ -- tmp2/1W
# tmp14/1W <-- ~ -- tmp2/1W
# tmp5/1W <-- & -- tmp4/1W, tmp2/1W
# tmp241/1W <-- ~ -- tmp2/1W
# tmp80/1W <-- ~ -- tmp2/1W
# tmp173/1W <-- ~ -- tmp2/1W
# tmp331/1W <-- ~ -- tmp2/1W
# tmp592/1W <-- ~ -- tmp2/1W
# tmp187/1W <-- ~ -- tmp2/1W
# tmp129/1W <-- ~ -- tmp2/1W
# tmp350/1W <-- ~ -- tmp2/1W
# tmp52/1W <-- ~ -- tmp2/1W
# tmp20/1W <-- ~ -- tmp2/1W
# tmp260/1W <-- ~ -- tmp2/1W
# tmp518/1W <-- ~ -- tmp2/1W
# tmp112/1W <-- ~ -- tmp2/1W
# tmp405/1W <-- ~ -- tmp2/1W
# tmp316/1W <-- ~ -- tmp2/1W
# tmp365/1W <-- ~ -- tmp2/1W
# tmp387/1W <-- & -- tmp385/1W, tmp386/1W
# tmp295/3W <-- c -- tmp294/1W, const_30_2/2C
# tmp646/1W <-- | -- tmp644/1W, tmp645/1W
# tmp563/1W <-- & -- tmp561/1W, tmp562/1W
# tmp332/1W <-- & -- tmp330/1W, tmp331/1W
# tmp366/1W <-- & -- tmp364/1W, tmp365/1W
# tmp502/1W <-- & -- tmp500/1W, tmp501/1W
# tmp296/1W <-- < -- temperature/3I, tmp295/3W
# tmp508/1W <-- ~ -- tmp280/1W
# tmp487/1W <-- ~ -- tmp280/1W
# tmp433/1W <-- ~ -- tmp280/1W
# tmp470/1W <-- ~ -- tmp280/1W
# tmp569/1W <-- ~ -- tmp280/1W
# tmp548/1W <-- ~ -- tmp280/1W
# tmp453/1W <-- ~ -- tmp280/1W
# tmp525/1W <-- ~ -- tmp280/1W
# pump/1O <-- w -- tmp646/1W
# tmp81/1W <-- & -- tmp79/1W, tmp80/1W
# tmp406/1W <-- & -- tmp404/1W, tmp405/1W
# tmp559/1W <-- > -- temperature/3I, tmp558/3W
# tmp650/4W <-- * -- tmp649/2W, const_55_3/2C
# tmp161/1W <-- & -- tmp159/1W, tmp160/1W
# tmp26/1W <-- ~ -- tmp25/1W
# tmp543/1W <-- ~ -- tmp11/1W
# tmp503/1W <-- ~ -- tmp11/1W
# tmp428/1W <-- ~ -- tmp11/1W
# tmp520/1W <-- ~ -- tmp11/1W
# tmp148/1W <-- ~ -- tmp11/1W
# tmp584/1W <-- ~ -- tmp11/1W
# tmp465/1W <-- ~ -- tmp11/1W
# tmp54/1W <-- ~ -- tmp11/1W
# tmp243/1W <-- ~ -- tmp11/1W
# tmp189/1W <-- ~ -- tmp11/1W
# tmp131/1W <-- ~ -- tmp11/1W
# tmp303/1W <-- ~ -- tmp11/1W
# tmp175/1W <-- ~ -- tmp11/1W
# tmp66/1W <-- ~ -- tmp11/1W
# tmp352/1W <-- ~ -- tmp11/1W
# tmp333/1W <-- ~ -- tmp11/1W
# tmp318/1W <-- ~ -- tmp11/1W
# tmp388/1W <-- ~ -- tmp11/1W
# tmp285/1W <-- ~ -- tmp11/1W
# tmp367/1W <-- ~ -- tmp11/1W
# tmp564/1W <-- ~ -- tmp11/1W
# tmp482/1W <-- ~ -- tmp11/1W
# tmp162/1W <-- ~ -- tmp11/1W
# tmp95/1W <-- ~ -- tmp11/1W
# tmp407/1W <-- ~ -- tmp11/1W
# tmp43/1W <-- ~ -- tmp11/1W
# tmp31/1W <-- ~ -- tmp11/1W
# tmp207/1W <-- ~ -- tmp11/1W
# tmp114/1W <-- ~ -- tmp11/1W
# tmp222/1W <-- ~ -- tmp11/1W
# tmp594/1W <-- ~ -- tmp11/1W
# tmp262/1W <-- ~ -- tmp11/1W
# tmp82/1W <-- ~ -- tmp11/1W
# tmp448/1W <-- ~ -- tmp11/1W
# tmp389/1W <-- & -- tmp387/1W, tmp388/1W
# tmp210/1W <-- ~ -- tmp26/1W
# tmp265/1W <-- ~ -- tmp26/1W
# tmp225/1W <-- ~ -- tmp26/1W
# tmp246/1W <-- ~ -- tmp26/1W
# tmp178/1W <-- ~ -- tmp26/1W
# tmp165/1W <-- ~ -- tmp26/1W
# tmp192/1W <-- ~ -- tmp26/1W
# tmp151/1W <-- ~ -- tmp26/1W
# tmp464/1W <-- & -- tmp462/1W, tmp463/1W
# tmp297/1W <-- ~ -- tmp296/1W
# tmp542/1W <-- & -- tmp540/1W, tmp541/1W
# tmp302/1W <-- & -- tmp300/1W, tmp301/1W
# tmp334/1W <-- & -- tmp332/1W, tmp333/1W
# tmp317/1W <-- & -- tmp315/1W, tmp316/1W
# tmp113/1W <-- & -- tmp111/1W, tmp112/1W
# tmp10/1W <-- & -- tmp9/1W, tmp6/1W
# tmp460/1W <-- < -- temperature/3I, tmp459/3W
# tmp493/1W <-- ~ -- tmp460/1W
# tmp653/4W <-- c -- tmp652/3W, tmp651/1W
# tmp565/1W <-- & -- tmp563/1W, tmp564/1W
# tmp567/1W <-- & -- tmp565/1W, tmp566/1W
# tmp65/1W <-- & -- tmp63/1W, tmp64/1W
# tmp544/1W <-- & -- tmp542/1W, tmp543/1W
# tmp546/1W <-- & -- tmp544/1W, tmp545/1W
# tmp53/1W <-- & -- tmp51/1W, tmp52/1W
# tmp593/1W <-- & -- tmp591/1W, tmp592/1W
# tmp583/1W <-- & -- tmp581/1W, tmp582/1W
# tmp221/1W <-- & -- tmp219/1W, tmp220/1W
# tmp223/1W <-- & -- tmp221/1W, tmp222/1W
# tmp242/1W <-- & -- tmp240/1W, tmp241/1W
# tmp42/1W <-- & -- tmp40/1W, tmp41/1W
# tmp147/1W <-- & -- tmp145/1W, tmp146/1W
# tmp447/1W <-- & -- tmp445/1W, tmp446/1W
# tmp38/1W <-- < -- temperature/3I, tmp37/3W
# tmp298/1W <-- | -- tmp293/1W, tmp297/1W
# tmp83/1W <-- & -- tmp81/1W, tmp82/1W
# tmp206/1W <-- & -- tmp204/1W, tmp205/1W
# tmp174/1W <-- & -- tmp172/1W, tmp173/1W
# tmp261/1W <-- & -- tmp259/1W, tmp260/1W
# tmp340/1W <-- ~ -- tmp298/1W
# tmp325/1W <-- ~ -- tmp298/1W
# tmp188/1W <-- & -- tmp186/1W, tmp187/1W
# tmp30/1W <-- & -- tmp28/1W, tmp29/1W
# tmp519/1W <-- & -- tmp517/1W, tmp518/1W
# tmp15/1W <-- & -- tmp13/1W, tmp14/1W
# tmp504/1W <-- & -- tmp502/1W, tmp503/1W
# tmp198/1W <-- ~ -- tmp170/1W
# tmp237/1W <-- > -- temperature/3I, tmp236/3W
# tmp94/1W <-- & -- tmp92/1W, tmp93/1W
# tmp77/1W <-- ~ -- tmp76/1W
# tmp126/1W <-- > -- temperature/3I, tmp125/3W
# tmp163/1W <-- & -- tmp161/1W, tmp162/1W
# tmp603/3W <-- x -- tmp5/1W, tmp602/3W, const_1_1/3C
# tmp585/1W <-- & -- tmp583/1W, tmp584/1W
# tmp149/1W <-- & -- tmp147/1W, tmp148/1W
# tmp466/1W <-- & -- tmp464/1W, tmp465/1W
# tmp408/1W <-- & -- tmp406/1W, tmp407/1W
# tmp410/1W <-- & -- tmp408/1W, tmp409/1W
# tmp115/1W <-- & -- tmp113/1W, tmp114/1W
# tmp55/1W <-- & -- tmp53/1W, tmp54/1W
# tmp391/1W <-- & -- tmp389/1W, tmp390/1W
# tmp96/1W <-- & -- tmp94/1W, tmp95/1W
# tmp468/1W <-- & -- tmp466/1W, tmp467/1W
# tmp547/1W <-- & -- tmp546/1W, tmp276/1W
# tmp654/5W <-- + -- tmp650/4W, tmp653/4W
# tmp319/1W <-- & -- tmp317/1W, tmp318/1W
# tmp321/1W <-- & -- tmp319/1W, tmp320/1W
# tmp97/1W <-- & -- tmp96/1W, tmp24/1W
# tmp521/1W <-- & -- tmp519/1W, tmp520/1W
# tmp32/1W <-- & -- tmp30/1W, tmp31/1W
# tmp84/1W <-- & -- tmp83/1W, tmp24/1W
# tmp44/1W <-- & -- tmp42/1W, tmp43/1W
# tmp449/1W <-- & -- tmp447/1W, tmp448/1W
# tmp85/1W <-- & -- tmp84/1W, tmp26/1W
# tmp208/1W <-- & -- tmp206/1W, tmp207/1W
# tmp164/1W <-- & -- tmp163/1W, tmp24/1W
# tmp304/1W <-- & -- tmp302/1W, tmp303/1W
# tmp322/1W <-- & -- tmp321/1W, tmp276/1W
# tmp506/1W <-- & -- tmp504/1W, tmp505/1W
# tmp150/1W <-- & -- tmp149/1W, tmp24/1W
# tmp56/1W <-- & -- tmp55/1W, tmp24/1W
# tmp612/3W <-- x -- tmp10/1W, tmp611/3W, const_1_1/3C
# tmp176/1W <-- & -- tmp174/1W, tmp175/1W
# tmp263/1W <-- & -- tmp261/1W, tmp262/1W
# tmp224/1W <-- & -- tmp223/1W, tmp24/1W
# tmp392/1W <-- & -- tmp391/1W, tmp276/1W
# tmp67/1W <-- & -- tmp65/1W, tmp66/1W
# tmp16/1W <-- & -- tmp15/1W, tmp11/1W
# tmp587/1W <-- & -- tmp585/1W, tmp586/1W
# tmp238/1W <-- ~ -- tmp237/1W
# tmp655/2W <-- s -- tmp654/5W ((0, 1))
# tmp264/1W <-- & -- tmp263/1W, tmp24/1W
# tmp323/1W <-- & -- tmp322/1W, tmp280/1W
# tmp568/1W <-- & -- tmp567/1W, tmp276/1W
# tmp45/1W <-- & -- tmp44/1W, tmp24/1W
# tmp209/1W <-- & -- tmp208/1W, tmp24/1W
# tmp211/1W <-- & -- tmp209/1W, tmp210/1W
# tmp393/1W <-- & -- tmp392/1W, tmp280/1W
# tmp87/1W <-- & -- tmp85/1W, tmp86/1W
# tmp324/1W <-- & -- tmp323/1W, tmp291/1W
# tmp33/1W <-- & -- tmp32/1W, tmp24/1W
# tmp212/1W <-- & -- tmp211/1W, tmp143/1W
# tmp570/1W <-- & -- tmp568/1W, tmp569/1W
# tmp273/1W <-- ~ -- tmp238/1W
# tmp326/1W <-- & -- tmp324/1W, tmp325/1W
# tmp589/1W <-- & -- tmp587/1W, tmp588/1W
# tmp46/1W <-- & -- tmp45/1W, tmp26/1W
# tmp68/1W <-- & -- tmp67/1W, tmp24/1W
# tmp395/1W <-- & -- tmp393/1W, tmp394/1W
# tmp226/1W <-- & -- tmp224/1W, tmp225/1W
# ac/2O <-- w -- tmp655/2W
# tmp397/1W <-- & -- tmp395/1W, tmp396/1W
# tmp398/1W <-- & -- tmp397/1W, tmp379/1W
# tmp411/1W <-- & -- tmp410/1W, tmp276/1W
# tmp116/1W <-- & -- tmp115/1W, tmp24/1W
# tmp166/1W <-- & -- tmp164/1W, tmp165/1W
# tmp102/1W <-- ~ -- tmp77/1W
# tmp571/1W <-- & -- tmp570/1W, tmp423/1W
# tmp59/1W <-- ~ -- tmp38/1W
# tmp71/1W <-- ~ -- tmp38/1W
# tmp190/1W <-- & -- tmp188/1W, tmp189/1W
# tmp98/1W <-- & -- tmp97/1W, tmp26/1W
# tmp451/1W <-- & -- tmp449/1W, tmp450/1W
# tmp469/1W <-- & -- tmp468/1W, tmp276/1W
# tmp152/1W <-- & -- tmp150/1W, tmp151/1W
# tmp549/1W <-- & -- tmp547/1W, tmp548/1W
# tmp523/1W <-- & -- tmp521/1W, tmp522/1W
# tmp34/1W <-- & -- tmp33/1W, tmp26/1W
# tmp327/1W <-- & -- tmp326/1W, tmp313/1W
# tmp88/1W <-- & -- tmp87/1W, tmp75/1W
# tmp57/1W <-- & -- tmp56/1W, tmp26/1W
# tmp306/1W <-- & -- tmp304/1W, tmp305/1W
# tmp507/1W <-- & -- tmp506/1W, tmp276/1W
# tmp214/1W <-- & -- tmp212/1W, tmp213/1W
# tmp177/1W <-- & -- tmp176/1W, tmp24/1W
# tmp604/3W <-- x -- tmp16/1W, tmp603/3W, const_5_5/3C
# tmp284/1W <-- & -- tmp282/1W, tmp283/1W
# tmp368/1W <-- & -- tmp366/1W, tmp367/1W
# tmp427/1W <-- & -- tmp425/1W, tmp426/1W
# tmp351/1W <-- & -- tmp349/1W, tmp350/1W
# tmp336/1W <-- & -- tmp334/1W, tmp335/1W
# tmp130/1W <-- & -- tmp128/1W, tmp129/1W
# tmp244/1W <-- & -- tmp242/1W, tmp243/1W
# tmp443/1W <-- | -- tmp438/1W, tmp442/1W
# tmp132/1W <-- & -- tmp130/1W, tmp131/1W
# tmp21/1W <-- & -- tmp19/1W, tmp20/1W
# tmp481/1W <-- & -- tmp479/1W, tmp480/1W
# tmp595/1W <-- & -- tmp593/1W, tmp594/1W
# tmp266/1W <-- & -- tmp264/1W, tmp265/1W
# tmp370/1W <-- & -- tmp368/1W, tmp369/1W
# tmp399/1W <-- & -- tmp398/1W, tmp383/1W
# tmp573/1W <-- & -- tmp571/1W, tmp572/1W
# tmp22/1W <-- & -- tmp21/1W, tmp11/1W
# tmp47/1W <-- & -- tmp46/1W, tmp35/1W
# tmp429/1W <-- & -- tmp427/1W, tmp428/1W
# tmp412/1W <-- & -- tmp411/1W, tmp280/1W
# tmp179/1W <-- & -- tmp177/1W, tmp178/1W
# tmp69/1W <-- & -- tmp68/1W, tmp26/1W
# tmp245/1W <-- & -- tmp244/1W, tmp24/1W
# tmp267/1W <-- & -- tmp266/1W, tmp143/1W
# tmp605/3W <-- x -- tmp34/1W, tmp604/3W, const_5_5/3C
# tmp227/1W <-- & -- tmp226/1W, tmp143/1W
# tmp509/1W <-- & -- tmp507/1W, tmp508/1W
# tmp483/1W <-- & -- tmp481/1W, tmp482/1W
# tmp153/1W <-- & -- tmp152/1W, tmp143/1W
# tmp89/1W <-- & -- tmp88/1W, tmp77/1W
# tmp307/1W <-- & -- tmp306/1W, tmp276/1W
# tmp597/1W <-- & -- tmp595/1W, tmp596/1W
# tmp308/1W <-- & -- tmp307/1W, tmp280/1W
# tmp471/1W <-- & -- tmp469/1W, tmp470/1W
# tmp117/1W <-- & -- tmp116/1W, tmp26/1W
# tmp524/1W <-- & -- tmp523/1W, tmp276/1W
# tmp371/1W <-- & -- tmp370/1W, tmp276/1W
# tmp191/1W <-- & -- tmp190/1W, tmp24/1W
# tmp100/1W <-- & -- tmp98/1W, tmp99/1W
# tmp167/1W <-- & -- tmp166/1W, tmp143/1W
# tmp286/1W <-- & -- tmp284/1W, tmp285/1W
# tmp491/1W <-- ~ -- tmp443/1W
# tmp474/1W <-- ~ -- tmp443/1W
# tmp472/1W <-- & -- tmp471/1W, tmp423/1W
# tmp353/1W <-- & -- tmp351/1W, tmp352/1W
# tmp473/1W <-- & -- tmp472/1W, tmp436/1W
# tmp550/1W <-- & -- tmp549/1W, tmp423/1W
# tmp485/1W <-- & -- tmp483/1W, tmp484/1W
# tmp510/1W <-- & -- tmp509/1W, tmp423/1W
# tmp452/1W <-- & -- tmp451/1W, tmp276/1W
# tmp23/1W <-- & -- tmp22/1W, tmp17/1W
# tmp58/1W <-- & -- tmp57/1W, tmp35/1W
# tmp599/1W <-- & -- tmp597/1W, tmp598/1W
# tmp431/1W <-- & -- tmp429/1W, tmp430/1W
# tmp70/1W <-- & -- tmp69/1W, tmp35/1W
# tmp215/1W <-- & -- tmp214/1W, tmp200/1W
# tmp247/1W <-- & -- tmp245/1W, tmp246/1W
# tmp119/1W <-- & -- tmp117/1W, tmp118/1W
# tmp168/1W <-- & -- tmp167/1W, tmp154/1W
# tmp229/1W <-- & -- tmp227/1W, tmp228/1W
# tmp309/1W <-- & -- tmp308/1W, tmp291/1W
# tmp454/1W <-- & -- tmp452/1W, tmp453/1W
# tmp180/1W <-- & -- tmp179/1W, tmp143/1W
# tmp269/1W <-- & -- tmp267/1W, tmp268/1W
# tmp181/1W <-- & -- tmp180/1W, tmp154/1W
# tmp48/1W <-- & -- tmp47/1W, tmp38/1W
# tmp337/1W <-- & -- tmp336/1W, tmp276/1W
# tmp355/1W <-- & -- tmp353/1W, tmp354/1W
# tmp133/1W <-- & -- tmp132/1W, tmp24/1W
# tmp72/1W <-- & -- tmp70/1W, tmp71/1W
# tmp288/1W <-- & -- tmp286/1W, tmp287/1W
# tmp606/3W <-- x -- tmp153/1W, tmp605/3W, const_6_6/3C
# tmp414/1W <-- & -- tmp412/1W, tmp413/1W
# tmp230/1W <-- & -- tmp229/1W, tmp200/1W
# tmp575/1W <-- & -- tmp573/1W, tmp574/1W
# tmp101/1W <-- & -- tmp100/1W, tmp75/1W
# tmp193/1W <-- & -- tmp191/1W, tmp192/1W
# tmp183/1W <-- & -- tmp181/1W, tmp182/1W
# tmp613/3W <-- x -- tmp23/1W, tmp612/3W, const_2_2/3C
# tmp486/1W <-- & -- tmp485/1W, tmp276/1W
# tmp432/1W <-- & -- tmp431/1W, tmp276/1W
# tmp488/1W <-- & -- tmp486/1W, tmp487/1W
# tmp475/1W <-- & -- tmp473/1W, tmp474/1W
# tmp310/1W <-- & -- tmp309/1W, tmp298/1W
# tmp194/1W <-- & -- tmp193/1W, tmp143/1W
# tmp552/1W <-- & -- tmp550/1W, tmp551/1W
# tmp60/1W <-- & -- tmp58/1W, tmp59/1W
# tmp434/1W <-- & -- tmp432/1W, tmp433/1W
# tmp512/1W <-- & -- tmp510/1W, tmp511/1W
# tmp121/1W <-- & -- tmp119/1W, tmp120/1W
# tmp289/1W <-- & -- tmp288/1W, tmp276/1W
# tmp526/1W <-- & -- tmp524/1W, tmp525/1W
# tmp513/1W <-- & -- tmp512/1W, tmp496/1W
# tmp476/1W <-- & -- tmp475/1W, tmp460/1W
# tmp61/1W <-- & -- tmp60/1W, tmp49/1W
# tmp372/1W <-- & -- tmp371/1W, tmp280/1W
# tmp74/1W <-- & -- tmp72/1W, tmp73/1W
# tmp134/1W <-- & -- tmp133/1W, tmp26/1W
# tmp338/1W <-- & -- tmp337/1W, tmp280/1W
# tmp416/1W <-- & -- tmp414/1W, tmp415/1W
# tmp339/1W <-- & -- tmp338/1W, tmp291/1W
# tmp614/3W <-- x -- tmp48/1W, tmp613/3W, const_3_3/3C
# tmp576/1W <-- & -- tmp575/1W, tmp534/1W
# tmp216/1W <-- & -- tmp215/1W, tmp202/1W
# tmp248/1W <-- & -- tmp247/1W, tmp143/1W
# tmp356/1W <-- & -- tmp355/1W, tmp276/1W
# tmp357/1W <-- & -- tmp356/1W, tmp280/1W
# tmp169/1W <-- & -- tmp168/1W, tmp157/1W
# tmp455/1W <-- & -- tmp454/1W, tmp423/1W
# tmp103/1W <-- & -- tmp101/1W, tmp102/1W
# tmp184/1W <-- & -- tmp183/1W, tmp170/1W
# tmp104/1W <-- & -- tmp103/1W, tmp90/1W
# tmp271/1W <-- & -- tmp269/1W, tmp270/1W
# tmp341/1W <-- & -- tmp339/1W, tmp340/1W
# tmp122/1W <-- & -- tmp121/1W, tmp105/1W
# tmp489/1W <-- & -- tmp488/1W, tmp423/1W
# tmp232/1W <-- & -- tmp230/1W, tmp231/1W
# tmp195/1W <-- & -- tmp194/1W, tmp154/1W
# tmp123/1W <-- & -- tmp122/1W, tmp109/1W
# tmp514/1W <-- & -- tmp513/1W, tmp498/1W
# tmp554/1W <-- & -- tmp552/1W, tmp553/1W
# tmp615/3W <-- x -- tmp61/1W, tmp614/3W, const_4_4/3C
# tmp616/3W <-- x -- tmp74/1W, tmp615/3W, const_2_2/3C
# tmp435/1W <-- & -- tmp434/1W, tmp423/1W
# tmp197/1W <-- & -- tmp195/1W, tmp196/1W
# tmp374/1W <-- & -- tmp372/1W, tmp373/1W
# tmp199/1W <-- & -- tmp197/1W, tmp198/1W
# tmp527/1W <-- & -- tmp526/1W, tmp423/1W
# tmp578/1W <-- & -- tmp576/1W, tmp577/1W
# tmp290/1W <-- & -- tmp289/1W, tmp280/1W
# tmp617/3W <-- x -- tmp89/1W, tmp616/3W, const_3_3/3C
# tmp529/1W <-- & -- tmp527/1W, tmp528/1W
# tmp136/1W <-- & -- tmp134/1W, tmp135/1W
# tmp456/1W <-- & -- tmp455/1W, tmp436/1W
# tmp579/1W <-- & -- tmp578/1W, tmp559/1W
# tmp417/1W <-- & -- tmp416/1W, tmp379/1W
# tmp359/1W <-- & -- tmp357/1W, tmp358/1W
# tmp618/3W <-- x -- tmp104/1W, tmp617/3W, const_2_2/3C
# tmp272/1W <-- & -- tmp271/1W, tmp234/1W
# tmp490/1W <-- & -- tmp489/1W, tmp436/1W
# tmp250/1W <-- & -- tmp248/1W, tmp249/1W
# tmp360/1W <-- & -- tmp359/1W, tmp345/1W
# tmp274/1W <-- & -- tmp272/1W, tmp273/1W
# tmp343/1W <-- & -- tmp341/1W, tmp342/1W
# tmp607/3W <-- x -- tmp290/1W, tmp606/3W, const_5_5/3C
# tmp252/1W <-- & -- tmp250/1W, tmp251/1W
# tmp233/1W <-- & -- tmp232/1W, tmp217/1W
# tmp619/3W <-- x -- tmp123/1W, tmp618/3W, const_2_2/3C
# tmp555/1W <-- & -- tmp554/1W, tmp534/1W
# tmp138/1W <-- & -- tmp136/1W, tmp137/1W
# tmp530/1W <-- & -- tmp529/1W, tmp496/1W
# tmp556/1W <-- & -- tmp555/1W, tmp538/1W
# tmp375/1W <-- & -- tmp374/1W, tmp345/1W
# tmp457/1W <-- & -- tmp456/1W, tmp443/1W
# tmp377/1W <-- & -- tmp375/1W, tmp376/1W
# tmp419/1W <-- & -- tmp417/1W, tmp418/1W
# tmp253/1W <-- & -- tmp252/1W, tmp234/1W
# tmp275/1W <-- & -- tmp274/1W, tmp257/1W
# tmp361/1W <-- & -- tmp360/1W, tmp347/1W
# tmp344/1W <-- & -- tmp343/1W, tmp328/1W
# tmp254/1W <-- & -- tmp253/1W, tmp238/1W
# tmp608/3W <-- x -- tmp435/1W, tmp607/3W, const_6_6/3C
# tmp492/1W <-- & -- tmp490/1W, tmp491/1W
# tmp139/1W <-- & -- tmp138/1W, tmp105/1W
# tmp532/1W <-- & -- tmp530/1W, tmp531/1W
# tmp378/1W <-- & -- tmp377/1W, tmp362/1W
# tmp533/1W <-- & -- tmp532/1W, tmp515/1W
# tmp420/1W <-- & -- tmp419/1W, tmp402/1W
# tmp494/1W <-- & -- tmp492/1W, tmp493/1W
# tmp609/3W <-- x -- tmp589/1W, tmp608/3W, const_1_1/3C
# tmp610/3W <-- x -- tmp600/1W, tmp609/3W, const_0_0/3C
# tmp495/1W <-- & -- tmp494/1W, tmp477/1W
# tmp141/1W <-- & -- tmp139/1W, tmp140/1W
# state_water/3R <-- r -- tmp610/3W
# tmp142/1W <-- & -- tmp141/1W, tmp126/1W
# tmp620/3W <-- x -- tmp142/1W, tmp619/3W, const_4_4/3C
# tmp621/3W <-- x -- tmp169/1W, tmp620/3W, const_3_3/3C
# tmp622/3W <-- x -- tmp184/1W, tmp621/3W, const_4_4/3C
# tmp623/3W <-- x -- tmp199/1W, tmp622/3W, const_2_2/3C
# tmp624/3W <-- x -- tmp216/1W, tmp623/3W, const_3_3/3C
# tmp625/3W <-- x -- tmp233/1W, tmp624/3W, const_2_2/3C
# tmp626/3W <-- x -- tmp254/1W, tmp625/3W, const_2_2/3C
# tmp627/3W <-- x -- tmp275/1W, tmp626/3W, const_4_4/3C
# tmp628/3W <-- x -- tmp310/1W, tmp627/3W, const_2_2/3C
# tmp629/3W <-- x -- tmp327/1W, tmp628/3W, const_3_3/3C
# tmp630/3W <-- x -- tmp344/1W, tmp629/3W, const_4_4/3C
# tmp631/3W <-- x -- tmp361/1W, tmp630/3W, const_3_3/3C
# tmp632/3W <-- x -- tmp378/1W, tmp631/3W, const_2_2/3C
# tmp633/3W <-- x -- tmp399/1W, tmp632/3W, const_2_2/3C
# tmp634/3W <-- x -- tmp420/1W, tmp633/3W, const_4_4/3C
# tmp635/3W <-- x -- tmp457/1W, tmp634/3W, const_2_2/3C
# tmp636/3W <-- x -- tmp476/1W, tmp635/3W, const_3_3/3C
# tmp637/3W <-- x -- tmp495/1W, tmp636/3W, const_4_4/3C
# tmp638/3W <-- x -- tmp514/1W, tmp637/3W, const_3_3/3C
# tmp639/3W <-- x -- tmp533/1W, tmp638/3W, const_2_2/3C
# tmp640/3W <-- x -- tmp556/1W, tmp639/3W, const_2_2/3C
# tmp641/3W <-- x -- tmp579/1W, tmp640/3W, const_4_4/3C
# tmp642/3W <-- x -- tmp599/1W, tmp641/3W, const_1_1/3C
# tmp643/3W <-- x -- tmp601/1W, tmp642/3W, const_0_0/3C
# state_temperature/3R <-- r -- tmp643/3W
# ()

# %% [markdown]
# ## Simulate the FSM

# %% [markdown]
# Rather than just give some random inputs, let's specify inputs to observe functionality. The sim.step method takes a dictionary mapping inputs to their values.  We could just specify the input set directly as a dictionary but it gets pretty ugly -- let's use some python to parse them up.

# %%
sim_inputs = {
    'start':   '11111111111111111111100',
    'reset':   '01000000000000000000000',
	'water':   ['0', '1', '2','3', '4', '5','6','7','7', '13','14','14','15','15','14','13','7','6','5','4','3','3','3'],
	'temperature':   ['0', '1', '2','1', '2', '3','4','5','6', '6','6','5','4','4','3','3','4','5','6','1','1','1','1']
    }

# %%
for cycle in range(len(sim_inputs['start'])):
    sim.step({w: int(v[cycle]) for w, v in sim_inputs.items()})

print("--- Simulation Results ---")
sim_trace.render_trace(trace_list=['start', 'reset', 'water', 'pump', 'temperature','ac','state_water', 'state_temperature'])
# Out:
# --- Simulation Results ---
# AttributeErrorTraceback (most recent call last)
# <ipython-input-8-b3fb3f24da03> in <module>()
#       3     sim.step({w: int(v[cycle]) for w, v in sim_inputs.items()})
#       4
# ----> 5 sim_trace.render_trace(trace_list=['start', 'reset', 'water', 'pump', 'temperature','ac','state_water', 'state_temperature'])
#
# C:\Users\mcmor\Anaconda2\lib\site-packages\pyrtl\simulation.pyc in render_trace(self, trace_list, file, render_cls, symbol_len, segment_size, segment_delim, extra_line)
#     889             from IPython.display import display, HTML, Javascript  # pylint: disable=import-error
#     890             from .inputoutput import trace_to_html
# --> 891             htmlstring = trace_to_html(self, trace_list=trace_list, sortkey=_trace_sort_key)
#     892             display(HTML(htmlstring))
#     893             display(Javascript('WaveDrom.ProcessAll()'))
#
# C:\Users\mcmor\Anaconda2\lib\site-packages\pyrtl\inputoutput.pyc in trace_to_html(simtrace, trace_list, sortkey)
#     454     bool_signal_template = '{ name: "%s",  wave: "%s" },'
#     455     int_signal_template = '{ name: "%s",  wave: "%s", data: [%s] },'
# --> 456     signals = [extract(w) for w in trace_list]
#     457     all_signals = '\n'.join(signals)
#     458     wave = wave_template % all_signals
#
# C:\Users\mcmor\Anaconda2\lib\site-packages\pyrtl\inputoutput.pyc in extract(w)
#     450             return bool_signal_template % (w.name, wavestring)
#     451         else:
# --> 452             return int_signal_template % (w.name, wavestring, datastring)
#     453
#     454     bool_signal_template = '{ name: "%s",  wave: "%s" },'
#
# AttributeError: 'str' object has no attribute 'name'

# %% [markdown]
# Also, to make our input/output easy to reason about let's **specify an order to the traces**

# %% [markdown]
# ## Create Verilog code

# %%
# Output to a Verilog file named 'fsm_plant.v'
with open('fsm_plant.v', 'w') as v_file:
   pyrtl.OutputToVerilog(v_file)

# Output of TestBench to a Verilog file named 'fsm_plant_tb.v'
with open('fsm_plant_tb.v', 'w') as tbfile:
    pyrtl.output_verilog_testbench(dest_file=tbfile, simulation_trace=sim_trace)
    #print(tbfile.getvalue())   

# Optimized Verilog
pyrtl.synthesize()
pyrtl.optimize()

# Optimized output to a Verilog file named 'fsm_plant_opt.v'
with open('fsm_plant_opt.v', 'w') as vfile:
    pyrtl.OutputToVerilog(vfile)
    #print(vfile.getvalue())
